# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_excel('/Users/ianmonroe/Desktop/DefSouthAm.xlsx')

# %%
data
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0            NaN        NaN        NaN                                  NaN
# 1        country       iso3    wdpa-id                            park name
# 2      Argentina        ARG         10                            Calilegua
# 3      Argentina        ARG         10                            Calilegua
# 4      Argentina        ARG         10                            Calilegua
# ...          ...        ...        ...                                  ...
# 22725  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22726  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22727  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22728  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22729  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
#
# ...

# %%
data.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0        NaN        NaN        NaN        NaN        NaN
# 1    country       iso3    wdpa-id  park name       year
# 2  Argentina        ARG         10  Calilegua       2001
# 3  Argentina        ARG         10  Calilegua       2002
# 4  Argentina        ARG         10  Calilegua       2003
#
#                                           Unnamed: 5  \
# 0                                                NaN
# 1  outside(up to 10 km from park boundary) defore...
# 2                                             3.7217
# 3                                             9.1801
# 4                                             1.2406
#
#                                           Unnamed: 6
# 0                                                NaN
# 1  inside (up to 10 km from park boundary) defore...
# 2                                              3.542
# 3                                             3.3495
# ...

# %%
data.drop(0)
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 1        country       iso3    wdpa-id                            park name
# 2      Argentina        ARG         10                            Calilegua
# 3      Argentina        ARG         10                            Calilegua
# 4      Argentina        ARG         10                            Calilegua
# 5      Argentina        ARG         10                            Calilegua
# ...          ...        ...        ...                                  ...
# 22725  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22726  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22727  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22728  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22729  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
#
# ...

# %%
data.drop(1)
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0            NaN        NaN        NaN                                  NaN
# 2      Argentina        ARG         10                            Calilegua
# 3      Argentina        ARG         10                            Calilegua
# 4      Argentina        ARG         10                            Calilegua
# 5      Argentina        ARG         10                            Calilegua
# ...          ...        ...        ...                                  ...
# 22725  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22726  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22727  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22728  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
# 22729  Venezuela        VEN      61899  Cuenca Alta y Media del Rfo Orituco
#
#       Unnamed: 4 Unnamed: 5 Unnamed: 6
# ...

# %%
for col in data.columns:
    print(col)
# Out:
# Unnamed: 0
# Unnamed: 1
# Unnamed: 2
# Unnamed: 3
# Unnamed: 4
# Unnamed: 5
# Unnamed: 6

# %%
data = data.rename(columns = {'Unnamed: 0': 'Country','Unnamed: 1': 'CouCode', 'Unnamed: 2': 'ParkID','Unnamed: 3': 'Park','Unnamed: 4': 'Year','Unnamed: 5': 'Outside','Unnamed: 6': 'Inside'})

# %%
dates = pd.date_range('2001', periods = 12)

# %%
len(data) #22730 rows imported
# Out:
# 22730

# %%
data.columns
# Out:
# Index(['Country', 'CouCode', 'ParkID', 'Park', 'Year', 'Outside', 'Inside'], dtype='object')

# %%
len(data.columns)
# Out:
# 7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22730 entries, 0 to 22729
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  22729 non-null  object
#  1   CouCode  22729 non-null  object
#  2   ParkID   22729 non-null  object
#  3   Park     22609 non-null  object
#  4   Year     22729 non-null  object
#  5   Outside  22729 non-null  object
#  6   Inside   22729 non-null  object
# dtypes: object(7)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#        Country CouCode     ParkID        Park   Year     Outside  Inside
# count    22729   22729      22729       22609  22729  22729.0000   22729
# unique      22      22       1603        1821     14  14822.0000   10104
# top     Brazil     BRA  555600000  Araucßrias   2012     99.3683       0
# freq     10908   10908       2064          36   1893   1838.0000    1996

# %%
data [['CouCode', 'ParkID', 'Year', 'Outside', 'Inside']]
# Out:
#       CouCode   ParkID  Year  \
# 0         NaN      NaN   NaN
# 1        iso3  wdpa-id  year
# 2         ARG       10  2001
# 3         ARG       10  2002
# 4         ARG       10  2003
# ...       ...      ...   ...
# 22725     VEN    61899  2008
# 22726     VEN    61899  2009
# 22727     VEN    61899  2010
# 22728     VEN    61899  2011
# 22729     VEN    61899  2012
#
#                                                  Outside  \
# 0                                                    NaN
# 1      outside(up to 10 km from park boundary) defore...
# 2                                                 3.7217
# 3                                                 9.1801
# 4                                                 1.2406
# ...                                                  ...
# 22725                                              5.878
# 22726                                              8.735
# 22727                                             5.1884
# ...

# %%
by_c = data.groupby ('Country')
print(by_c)

# %%
for Country, data in by_c:
    print(data)
# Out:
#        Country CouCode  ParkID        Park  Year  Outside   Inside
# 2    Argentina     ARG      10   Calilegua  2001   3.7217    3.542
# 3    Argentina     ARG      10   Calilegua  2002   9.1801   3.3495
# 4    Argentina     ARG      10   Calilegua  2003   1.2406    4.235
# 5    Argentina     ARG      10   Calilegua  2004   9.9244   0.5236
# 6    Argentina     ARG      10   Calilegua  2005  43.5434   3.6883
# ..         ...     ...     ...         ...   ...      ...      ...
# 405  Argentina     ARG  900725  Las Yungas  2008  51.1428  27.2143
# 406  Argentina     ARG  900725  Las Yungas  2009  16.8411   7.9304
# 407  Argentina     ARG  900725  Las Yungas  2010  24.9543   10.869
# 408  Argentina     ARG  900725  Las Yungas  2011  15.2468   6.3518
# 409  Argentina     ARG  900725  Las Yungas  2012  13.2971   9.1668
#
# [408 rows x 7 columns]
#     Country CouCode     ParkID                 Park  Year  Outside   Inside
# ...

# %%
data
# Out:
#    Country CouCode   ParkID       Park  Year  \
# 1  country    iso3  wdpa-id  park name  year
#
#                                              Outside  \
# 1  outside(up to 10 km from park boundary) defore...
#
#                                               Inside
# 1  inside (up to 10 km from park boundary) defore...

# %%
data['Country'] = data['Country'].astype('category')

# %%
data['CouCode'] = data['CouCode'].astype(str)

# %%
data['ParkID'] = data['ParkID'].astype('category')

# %%
data['Park'] = data['Park'].astype(str)

# %%
data['Year'] = data['Year'].astype(str)

# %%
data['Outside'] = data['Outside'].astype(float)

# %%
data['Inside'] = data['Inside'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  0 non-null      category
#  1   CouCode  0 non-null      object
#  2   ParkID   0 non-null      category
#  3   Park     0 non-null      object
#  4   Year     0 non-null      object
#  5   Outside  0 non-null      float64
#  6   Inside   0 non-null      float64
# dtypes: category(2), float64(2), object(3)
# memory usage: 160.0+ bytes

# %%
data.columns = data.columns.to_series().apply(lambda x:
                                             x.strip())

# %%
Arg = data[0:408] #Argentina
Bel = data[408:816] #Belize
Bov = data[816:1188] #Bolivia
Bra = data[1188:12096]#Brazil
Col = data [12097:15912] #Colombia
Cost = data[15912:16728] #Costa Rica
Cub = data[16728:17136] #Cuba
DR = data[17136:17460] #Dominican Republic
Ecu = data [17460:17712] #Ecuador
ElSa = data [17712:17748] #El Salvador
Guat = data [17748:18540] #Guatemala
Guy = data [18540:18600] #Guyana
Hon = data [18600:18876] #Honduras
Jam = data [18876:19176] #Jamaica
Mex = data[19176:20256] #Mexico
Nic = data [20256:20496] #Nicaragua
Pan = data [20496:20856] #Panama
Para = data [20856:21036] #Paraguay
Per = data [21036:21936] #Peru
Sur = data [21936:22080] #Suriname
Ven = data [22080:22730] #Venezuela

# %%
Filterout = data.Outside > 50.0

# %%
data[Filterout]
# Out:
# Empty DataFrame
# Columns: [Country, CouCode, ParkID, Park, Year, Outside, Inside]
# Index: []

# %%
Filterin = data.Inside > 50.0
data[Filterin]
# Out:
# Empty DataFrame
# Columns: [Country, CouCode, ParkID, Park, Year, Outside, Inside]
# Index: []

# %%
Hidefout = data[Filterout]
Hidefin = data [Filterin]

# %%
Hidefout
# Out:
# Empty DataFrame
# Columns: [Country, CouCode, ParkID, Park, Year, Outside, Inside]
# Index: []

# %%
Hidefboth = data[Filterin & Filterout]

# %%
Hidefboth
# Out:
# Empty DataFrame
# Columns: [Country, CouCode, ParkID, Park, Year, Outside, Inside]
# Index: []

# %%
data[data.ParkID == 10]
# Out:
# Empty DataFrame
# Columns: [Country, CouCode, ParkID, Park, Year, Outside, Inside]
# Index: []

# %%
data[data.CouCode == 'BRA']
# Out:
#       Country CouCode     ParkID            Park  Year  Outside   Inside
# 1190   Brazil     BRA         43   Rio Trombetas  2001  19.6389   1.6842
# 1191   Brazil     BRA         43   Rio Trombetas  2002  10.8214   2.3631
# 1192   Brazil     BRA         43   Rio Trombetas  2003   8.0588   2.1053
# 1193   Brazil     BRA         43   Rio Trombetas  2004  21.0990   1.3672
# 1194   Brazil     BRA         43   Rio Trombetas  2005   5.5252   2.1951
# ...       ...     ...        ...             ...   ...      ...      ...
# 12093  Brazil     BRA  555500000  TurT/Mariquita  2008  99.3683  25.6795
# 12094  Brazil     BRA  555500000  TurT/Mariquita  2009  54.3686  65.8734
# 12095  Brazil     BRA  555500000  TurT/Mariquita  2010  99.3683  99.3683
# 12096  Brazil     BRA  555500000  TurT/Mariquita  2011  86.8927  75.9219
# 12097  Brazil     BRA  555500000  TurT/Mariquita  2012  14.8057  25.6795
#
# [10908 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
vis1 = sns.distplot(data['Inside'])

# %%
vis2 = sns.distplot(data['Outside'])

# %%
 vis3 = sns.jointplot(x =Pan['Inside'], y = Pan['Outside'], kind = 'scatter') #Panama - Jointplot of Inside and Outside deforestation rates

# %%
vis5 = sns.lmplot(data = data, x ='Inside', y = 'Outside', fit_reg = True )

# %%
vis6 = sns.lmplot(data=Hidefin, x = 'Inside', y = 'Outside', fit_reg = False , hue = 'Country', height = 12, aspect = 1 )

# %%
sns.regplot(data = Per, x = 'Outside', y = 'Inside')
# Out:
# <AxesSubplot:xlabel='Outside', ylabel='Inside'>

# %%
vis7 = sns.lmplot(data = Hidefboth, x = 'Inside', y = 'Outside', fit_reg = True)

# %%
#For Parks with Deforestation Rates greater than 50% inside and outside have an average deforestation rate of 88% outside and 85.58% inside
# Std. Deviation fromt the mean is notable; 16.08% from the outside, and 17.21% inside.
# IQR tells us that the majority of parks with high rates fall within the 99% Deforestation range. a

# %%
Hidefboth.describe()
# Out:
#            Outside      Inside
# count  1450.000000  1450.00000
# mean     88.004356    85.58847
# std      16.087637    17.21714
# min      50.001400    50.01910
# 25%      76.626475    70.33940
# 50%      99.368300    99.36830
# 75%      99.368300    99.36830
# max      99.368300    99.36830

# %%
Filter3 = data.Outside < 50.0
Filter4 = data.Inside < 50.0

# %%
Lowdefboth = data[Filter3 & Filter4]

# %%
vis7 = sns.lmplot(data = Lowdefboth, x = 'Inside', y = 'Outside', fit_reg = True)

# %%
Lowdefboth.describe()
# Out:
#             Outside        Inside
# count  17831.000000  17831.000000
# mean      12.708236      7.141139
# std       12.573862      9.651933
# min        0.000000      0.000000
# 25%        2.551550      0.730050
# 50%        8.502600      3.163400
# 75%       19.427100      9.418800
# max       49.996600     49.951200

# %%
#For parks with Deforestation Rates Less than 50% inside and outside:
# - The average rate of deforestation is 12.7% outside and 7.1% inside
# the std. deviation from the mean is 12.5% outside (nearly equal to the avg.) and 9.6% inside.
#The IQR shows more variability with the:
#75th percentile being 19.4% outside, 9.4% inside
#25th percentile being 2.5% outside, 0.7% inside

# %%
Filter5 = data.Outside < 20.0
Filter6 = data.Inside < 20.0

# %%
Lowerdefb = data[Filter5 & Filter6]

# %%
vis8 = sns.lmplot(data = Lowerdefb, x = 'Inside', y = 'Outside', fit_reg = True)

# %%
Lowerdefb.describe()
# Out:
#              ParkID       Outside        Inside
# count  1.279000e+04  12790.000000  12790.000000
# mean   9.248604e+07      6.328017      3.634945
# std    2.067708e+08      5.578038      4.365251
# min    1.000000e+01      0.000000      0.000000
# 25%    3.391300e+04      1.439925      0.411400
# 50%    1.667315e+05      4.824550      1.864550
# 75%    3.524570e+05     10.250375      5.210300
# max    5.556000e+08     19.997700     19.995500

# %%
LowinHiout = data[Filter4 & Filterout]

# %%
LowinHiout.describe()
# Out:
#            Outside       Inside
# count  2773.000000  2773.000000
# mean     88.418497    17.002175
# std     127.782001    14.242224
# min      50.001600     0.000000
# 25%      62.135600     4.532200
# 50%      81.574200    13.025800
# 75%      99.368300    27.442400
# max    2012.000000    49.944300

# %%
#Few Parks with High Outside Deforestation Rates and Low inside Deforestation Rates.
#mean for outside is 88% ; inside is 17%
#std dev for outside is 127.78%! For inside, the std. dev is 14.24%

# %%
HiinLowout = data[Filterin & Filter3]

# %%
vis10 = sns.lmplot(data = HiinLowout, x = 'Inside', y = 'Outside', fit_reg = True)

# %%
HiinLowout.describe()
# Out:
#           Outside      Inside
# count  674.000000  674.000000
# mean    29.279272   74.896941
# std     13.519292   18.020537
# min      0.000000   50.162800
# 25%     18.836025   58.616200
# 50%     30.145500   70.661450
# 75%     40.893500   98.763575
# max     49.967300   99.368300

# %%
j = sns.jointplot(data = data, x = 'Inside', y = 'Outside', kind = 'hex')
j.ax_marg_x.set_xlim(0,100)
j.ax_marg_y.set_ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
plt.hist(data[data.Country == 'Argentina'].Inside)
plt.show()

# %%
plt.hist([data[data.Country == 'Brazil'].Outside, data[data.Country == 'Argentina'].Outside], bins = 15, stacked = True)
plt.show()

# %%
for Cou in data.Country.cat.categories:
    print(Cou)
# Out:
# Argentina
# Belize
# Bolivia
# Brazil
# Colombia
# Costa Rica
# Cuba
# Dominican Republic
# Ecuador
# El Salvador
# Guatemala
# Guyana
# Honduras
# Jamaica
# Mexico
# Nicaragua
# Panama
# Paraguay
# Peru
# Suriname
# Venezuela
# country

# %%
list1 = list()
mylabels = list()
for Cou in data.Country.cat.categories:
    list1.append(data[data.Country == Cou].Inside)
    mylabels.append(Cou)
h = plt.hist(list1, bins = 30, stacked = True,rwidth = 1, label = mylabels)
plt.legend()
plt.show()
